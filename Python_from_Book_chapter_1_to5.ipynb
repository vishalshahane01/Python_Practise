# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalshahane01/Python_Practise/blob/main/Python_from_Book_chapter_1_to5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
# working with variables Variables are like containers used to store information.
# You create one using the assignment operator (=).

greeting="Hello World"
print(greeting)
# Out:
# Hello World

# %%
#Understanding Strings
# In Python, text is referred to as a string.
# Strings can be created with either single (') or double (") quotation marks.
# String Methods: These are special functions used to manipulate text.
# Changing Case: You can use methods to change text to uppercase or lowercase.
# Cleaning Data: Methods can remove extra whitespace from the beginning or end of a string.
# Finding Text: The .find() method helps you locate a specific "substring" within a larger string.

Data="Understanding Strings In Python, text is referred to as a string.Strings can be created with either single  or double quotation marks. String Methods: These are special functions used to manipulate text.Changing Case You can use methods to change text to uppercase or lowercase. Cleaning Data: Methods can remove extra whitespace from the beginning or end of a string. Finding Text: The method helps you locate a specific  within a larger string."
Data.find("Strings")
# Out:
# 14

# %%
# Here’s how you could write the paragraph as a multiline string using the backslash method:
paragraph = "This planet has—or rather had—a problem, which was \
this: most of the people living on it were unhappy for pretty much \
of the time. Many solutions were suggested for this problem, but \
most of these were largely concerned with the movements of small \
green pieces of paper, which is odd because on the whole it wasn't \
the small green pieces of paper that were unhappy."
print(paragraph)
# Out:
# This planet has—or rather had—a problem, which was this: most of the people living on it were unhappy for pretty much of the time. Many solutions were suggested for this problem, but most of these were largely concerned with the movements of small green pieces of paper, which is odd because on the whole it wasn't the small green pieces of paper that were unhappy.

# %%
# You can also create multiline strings using triple quotes (""" or ''') as delimiters. Here’s how to write a long paragraph using this approach:
paragraph = """This planet has—or rather had—a problem, which was
this: most of the people living on it were unhappy for pretty much
of the time. Many solutions were suggested for this problem, but
most of these were largely concerned with the movements of small
green pieces of paper, which is odd because on the whole it wasn't
the small green pieces of paper that were unhappy."""
print(paragraph)
# Out:
# This planet has—or rather had—a problem, which was
# this: most of the people living on it were unhappy for pretty much
# of the time. Many solutions were suggested for this problem, but
# most of these were largely concerned with the movements of small
# green pieces of paper, which is odd because on the whole it wasn't
# the small green pieces of paper that were unhappy.

# %%
>>> print("""An example of a
      string that spans across multiple lines
            and also preserves whitespace.""")
# Out:
# An example of a
#       string that spans across multiple lines
#             and also preserves whitespace.

# %%
#  Print a string that uses double quotation marks inside the string.
print('There are "double Quotes" inside this string')
# Print a string that uses an apostrophe inside the string.
print("This string's got an apostrophe.")

# Print a string that spans multiple lines with whitespace preserved.
print("""This string spans
      multiple lines.""")

 #Print a string that is coded on multiple lines but gets printed on a single line.
print('hi this is the string \
that is on multiple lines \
but gets printed on single line \
with the help of "backslash" ')
# Out:
# There are "double Quotes" inside this string
# This string's got an apostrophe.
# This string spans
#       multiple lines.
# hi this is the string that is on multiple lines but gets printed on single line with the help of "backslash"

# %%
# Basic Arithmetic: You can use Python as a calculator\
>>> 1+1
# Out:
# 2

# %%
# F-Strings: A modern way to combine strings and numbers in a print statement is using "f-strings".
name = "vishal"
heads=1
print(f"{name} has heads {heads}")
# Out:
# vishal has heads 1

# %%
print(f"{name} hi how are you")
# Out:
# vishal hi how are you

# %%
# String Indexing and Slicing
# Indexing: Accessing a single character by its position using square brackets, like flavor[0] to get the first letter and -1 to get last letter

print("flavor"[-1] )

#Slicing: Extracting a portion of a string by using a colon, such as flavor[0:3] to get the first three characters
"nederlands"[0:6]
# Out:
# r
# 'nederl'

# %%
# Concatenation, which joins two strings together
#Indexing, which gets a single character from a string
#Slicing, which gets several characters from a string at once


# string Concatination
string1 = "abra"
string2 = "cadabra"
magic_string = string1 + string2
print(magic_string)
#You can use string concatenation to join two related strings, such as joining a first name and a last name into a full name:

first_name = "Arthur"
last_name = "Dent"
full_name = first_name + " " + last_name
print(f"\n {full_name}")
# Out:
# abracadabra
#
#  Arthur Dent

# %%
#String Indexing
#Each character in a string has a numbered position called an index.
flavor = "fig pie"
print(flavor[0])
print(flavor[0:3])
print(flavor[2:])
# Out:
# f
# fig
# g pie

# %%
 #Create a string and print its length using len().
hi="words with spaces"
print(len(hi))

#Create two strings, concatenate them, and print the resulting string.
string1 = "abra"
string2 = "cadabra"
magic_string = string1 + string2
print(magic_string)

# Create two strings, use concatenation to add a space between them, and print the result.
first_name = "Arthur"
last_name = "Dent"
full_name = first_name + " " + last_name
print(f"\n {full_name}")

# Print the string "zing" by using slice notation to specify the correct range of characters in the string "bazinga"
string = "bazinga"
print(string[2:6])
# Out:
# 17
# abracadabra
#
#  Arthur Dent
# zing

# %%
#Converting String Case
print("Jean-Luc Picard".lower())

name = "Jean-Luc Picard"
print(f"\n 2.  {name.lower()}")
# Out:
# jean-luc picard
#
#  2.  jean-luc picard

# %%
# Strip a string
name = "Jean-Luc Picard      "
print(f"1. {name.rstrip()}")
# Left Strip
name = "     Jean-Luc Picard"
print(f"2. {name.lstrip()}")

name = " Jean-Luc Picard "
print(f"3. {name.strip()}")
# Out:
# 1. Jean-Luc Picard
# 2. Jean-Luc Picard
# 3. Jean-Luc Picard

# %%
# Determine If a String Starts or Ends With a Particular String
name = "Jean-Luc Picard"
print(f"1. {name.startswith('Jean')}")
print(f"2. {name.endswith('Picard')}")
print(f"3. {name.endswith('hygrt')}")
print(f"4. {name.startswith('picard')}")
# Out:
# 1. True
# 2. True
# 3. False
# 4. False

# %%
#Write a program that converts the following strings to lowercase:"Animals", "Badger", "Honey Bee", "Honey Badger". Print each lowercase string on a separate line.
print("Animals".lower())
print("Badger".lower())
print("Honey Bee".lower())
print("Honey Badger".lower())
string=("Animals","Badger","Honey Bee","Honey Badger")
#
# Out:
# animals
# badger
# honey bee
# honey badger

# %%
# Write a program that prints out the result of .startswith("be") on each of the following strings:
string1 = "Becomes"
string2 = "becomes"
string3 = "BEAR"
string4 = " bEautiful"
print(string1.lower().startswith("be"))
print(string2.lower().startswith("be"))
print(string3.lower().startswith("be"))
print(string4.lstrip().lower().startswith("be"))
# Out:
# True
# True
# True
# True

# %%
prompt = "Hey, what's up? "
user_input = input(prompt)
print("You said: " + user_input)
# Out:
# Hey, what's up? hello
# You said: hello

# %%
response = input("please enter input name ")
shouted_response = response.upper()
print("Well, if you insist..." + shouted_response)
# Out:
# please enter input name vishal
# Well, if you insist...VISHAL

# %%
#Write a program that takes input from the user and displays that input back.
prompt=input("enter your name")
print("your input is   "+ prompt)

# Write a program that takes input from the user and displays the input in lowercase.
print("your input in lower case is  "+ prompt.lower())
#Write a program that takes input from the user and displays the number of characters in the input.
print("your input length is: " + str(len(prompt))) # str is compulsory for concatination
# Out:
# enter your namefjufwjvvkERRVfvs
# your input is   fjufwjvvkERRVfvs
# your input in lower case is  fjufwjvvkerrvfvs
# your input length is: 16

# %%
# Integers vs. Floats: The difference between whole numbers (integers) and numbers with decimal points (floating-point numbers).
# Arithmetic Operators: Using Python for calculations like addition, subtraction, and more complex expressions.

# %%
#When you get user input using input(), the result is always a string.
# Using Strings With Arithmetic Operators
num = "2"
num + num
# Out:
# '22'

# %%
#Converting Strings to Numbers
#The TypeError examples in the previous section highlight a common problem when applying user input to an operation that requires a
# number and not a string: type mismatches.
num = input("Enter a number to be doubled: ")
doubled_num = num * 2
print(doubled_num) #Remember, input() always returns a string, so if you input 2, then num is assigned the string "2", not the integer 2.
# Out:
# Enter a number to be doubled: 2
# 22

# %%
# int() stands for integer and converts objects into whole numbers,
# whereas float() stands for сoating-point number and converts objects into numbers with decimal points.
print(int("12"))
float("12")
# Out:
# 12
# 12.0

# %%
# fix the problem by passing num to either int() or float(). Since the prompts asks the user to input a number, and not specifically an integer, let’s convert num to a floating-point number:
num = input("Enter a number to be doubled: ")
doubled_num = float(num) * 2
print(doubled_num)
# Out:
# Enter a number to be doubled: 2
# 4.0

# %%
# Create a string containing an integer, then convert that string into an actual integer object using int(). Test that your new object is
# a number by multiplying it by another number and displaying the result.
string=12
result=int(string)*2
print(result)
 #Repeat the previous exercise, but use a floating-point number andfloat().
new_result=float(string)*2
print(new_result)
# Out:
# 24
# 24.0

# %%
#  Streamline Your Print Statements
name = "Zaphod"
heads = 2
arms = 3
print(name + " has " + str(heads) + " heads and " + str(arms) + " arms")
print( f"{name} has {heads} heads and {arms} arms")# fstring is the easiest
# Out:
# Zaphod has 2 heads and 3 arms
# Zaphod has 2 heads and 3 arms

# %%
"the surprise is in here somewhere".find("surprise")
# Out:
# 4

# %%
# Keep in mind that this matching is done exactly, character by character, and is case-sensitive.
#For example, if you try to find "SURPRISE", the .find() method returns -1
 "the surprise is in here somewhere".find("SURPRISE")
# Out:
# -1

# %%
# find() only returns the index of the first appearance, starting from the beginning of the string:
"I put a string in your string".find("string")
# Out:
# 8

# %%
# If you want to find an integer in a string, you need to pass the integer to .find() as a string.
# If you do pass something other than a string to .find(), Python raises a TypeError:
# "My number is 555-555-5555".find(5)
"My number is 555-555-5555".find("5")
# Out:
# 13

# %%
#just like .find(), you tack .replace() on to the end of a variable or string literal.
#In this case, though, you need to put two strings inside of the parentheses in .replace() and separate them with a comma.
#Thefirst string is the substring to find, and the second string is the string to replace each occurrence of the substring with

my_story = "I'm telling you the truth; nothing but the truth!"
my_story.replace("the truth", "lies")
# Out:
# "I'm telling you lies; nothing but lies!"

# %%
print(my_story)
#To change the value of my_story, you need to reassign to it the new value returned by .replace():
my_story = my_story.replace("the truth", "lies")
my_story
# Out:
# I'm telling you the truth; nothing but the truth!
# "I'm telling you lies; nothing but lies!"

# %%
#In one line of code, display the result of trying to .find() the substring "a" in the string "AAA". The result should be -1.
"AAA is AAA AAA".find("a")
# Out:
# -1

# %%
 #Replace every occurrence of the character "s" with "x" in the string "Somebody said something to Samantha."
 "Somebody said something to Samantha.".replace("s","x")
# Out:
# 'Somebody xaid xomething to Samantha.'

# %%
# Write and test a script that accepts user input using the input()function
# and displays the result of trying to .find() a particular letter in that input.
sent=input("Please Enter your sentence: ")
lett=input("Please Enter your letter ")
sent.find(lett)
# Out:
# Please Enter your sentence: hi how are you
# Please Enter your letter o
# 4

# %%
# making the following changes to lower-case letters:
#The letter a becomes 4
# The letter b becomes 8
# The letter e becomes 3
# The letter l becomes 1
# The letter o becomes 0
# The letter s becomes 5
# The letter t becomes 7
my_text=input("please enter your text: ")
my_text=my_text.lower().replace("a","4")
my_text=my_text.replace("b","8")
my_text=my_text.replace("e","3")
my_text=my_text.replace("l","1")
my_text=my_text.replace("o","0")
my_text=my_text.replace("s","5")
my_text=my_text.replace("t","7")
my_text
# Out:
# please enter your text:  I like to eat eggs and spam
# ' i 1ik3 70 347 3gg5 4nd 5p4m'

# %%
string="1234"
string
# Out:
# '1234'

# %%
topping1 = "Peanut Butter"
topping2 = "Jelly"
sandwich=topping1+" & "+topping2
sandwich
# Out:
# 'Peanut Butter & Jelly'

# %% [markdown]
# # Numbers and Math
# Python has three built-in number data types: integers, floating-point
# numbers, and complex numbers.

# %%
# An integer is a whole number with no decimal places.
type(1)
# Out:
# int

# %%
#You can create an integer by simply typing the number explicitly or using the int() function.
# In Chapter 4, you learned how to convert a string containing an integer to a number using int().
# For example, the following converts the string "25" to the integer 25:
int("25")
# Out:
# 25

# %%
# In Python, you can’t use commas to group digits in integer literals, but you can use an underscore (_).
#The value 1_000_000 expresses one million in a more readable manner.
1_000_000
# Out:
# 1000000

# %%
# A сoating-point number, or сoat for short, is a number with a decimal place.
# 1.0 is a floating-point number, as is -2.75. The name of a floating-point data type is float:
print(type(1.0))

# Like int(), float() can be used to convert
# a string containing a number to a floating-point number:
print(float("1.25"))

#Floating-point literals can be created in three different ways.
# 1. 1000000.0
# 2. 1_000_000.0
# 3. 1e6
# Out:
# <class 'float'>
# 1.25

# %%
# Write a script that creates the two variables, num1 and num2.
# Both num1 and num2 should be assigned the integer literal 25,000,000,
# one written with underscored and one without.
#Print num1 and num2 on two separate lines.
num1=25_000_000
print(num1)
num2=25000000
print(num2)
# Out:
# 25000000
# 25000000

# %%
# Write a script that assigns the floating-point literal 175000.0 to the variable num using exponential notation,
# and then prints num in the interactive window.
num=175e3
print(num)
# Out:
# 175000.0

# %%
# In IDLE’s interactive window, try and find the smallest exponent N so that 2e<N>, where <N> is replaced with your number, returns inf.
print(2e308)
# Out:
# inf

# %% [markdown]
# Arithmetic Operators and
# Expressions

# %%
1+2
# Out:
# 3

# %%
1.0 + 2
# Python can evaluate 1+1 just fine, but 1 + 1 is the preferred format because it’s generally considered easier to read.
# This rule of thumb applies to all of the operators in this section.
# Out:
# 3.0

# %%
# To subtract two numbers, just put a - in between them
2 - 1
3.0 - 1
# Out:
# 2.0

# %%
 1 - -3

1 --3

1- -3

1--3
# Out:
# 4

# %%
# Of the four examples above, the first is the most PEP 8 compliant.
# That said, you can surround -3 with parentheses to make it even
# clearer that the second - is modifying 3:
1 - (-3)
# Out:
# 4

# %%
# Using parentheses is a good idea because it makes the code more explicit.
# **Computers execute code, but humans read code.**
# Anything you can do to make your code easier to read and understand is a good thing.

# %% [markdown]
# Multiplication

# %%
print(3 * 3)
print(3.0 * 3)
# Out:
# 9
# 9.0

# %% [markdown]
# Division

# %%
# Unlike addition, subtraction, and multiplication, division with the / operator always returns a float.

9/3

# If you want to make sure that you get an integer after dividing two numbers,
# you can use int() to convertthe result:

print(int(9/3))
# Out:
# 3

# %%
# Keep in mind that int() discards any fractional part of the number:
int(5.0 / 2)
# Out:
# 2

# %%
# If writing int(5.0 / 2) seems a little long-winded to you, Python provides a second division operator, //, called the integer division operator:
print(5.0 // 2)

#The // operator first divides the number on the left by the number on the right and then rounds down to an integer.
# This might not give the value you expect when one of the numbers is negative.
print( -3 // 2)

# On the other hand, 3 // 2 returns 1
print(3 // 2)

# Python gives you a ZeroDivisionError, letting you know that you just
# tried to break a fundamental rule of the universe.
# Out:
# 2.0
# -2
# 1

# %% [markdown]
# Exponents

# %%
print(2 ** 2)
print(2 ** 3)

# Exponents don’t have to be integers. They can also be floats:
print(2 ** 0.5)
print(2 ** -1)
# Out:
# 4
# 8
# 1.4142135623730951
# 0.5

# %% [markdown]
# The Modulus Operator
# The % operator, or the modulus, returns the remainder of dividing
# the left operand by the right operand:

# %%
print(5 % 3)
print(5.0 % 3)
print(7 % 3)
# Out:
# 2
# 2.0
# 1

# %% [markdown]
# Arithmetic Expressions
# You can combine operators to form complex expressions. An expression is a combination of numbers, operators, and parentheses that
# Python can compute, or evaluate, to return a value.

# %%
print(2*3 -1 )
# The *, /, //, and % operators all have equal precedence, or priority,
# Out:
# 5

# %%
# A sample run of the program should look like this (with example input that has been provided by the user included below):
# Enter a base: 1.2
# Enter an exponent: 3
# 1.2 to the power of 3 = 1.7279999999999998
base=float(input("enter base:  "))
expo=float(input("Enter an exponent: "))
print(f"{base} to the power of {expo} = {float(base)**float(expo)}")
# Out:
# enter base:  1.2
# Enter an exponent: 3
# 1.2 to the power of 3.0 = 1.7279999999999998

# %%
0.1+0.2
# Out:
# 0.30000000000000004

# %% [markdown]
#  Math Functions and Number
# Methods

# %%
# You can use round() to round a number to the nearest integer:
print(round(3.3))
print(round(3.7))
print("\n")
# When you round ties to even, you first look at the digit one decimal place to the left of the last digit in the tie.
# If that digit is even, you round down.
# If the digit is odd, you round up. That’s why 2.5 rounds down to 2 and 3.5 round up to 4.
print(round(2.5))
print(round(3.5))
print("\n")
# You can round a number to a given number of decimal places by passing a second argument to round():
print(round(3.1459,3))
print(round(2.718728,2))
# The second argument of round() must be an integer. If it isn’t, Python raises a TypeError:
# The absolute value of a number n is just n if n is positive, and -n if n is negative.
# For example, the absolute value of 3 is 3, while the absolute value of -5 is 5.
print("\n")
print(abs(3.0))
print(abs(-5))
# You can also use the pow() function. pow() takes two arguments.
print('\n')
print(pow(2,3))
print('\n')
# pow(x, y, z) is equivalent to (x ** y) % z. Here’s an example with x = 2, y = 3, and z = 2:
print(pow(2,3,2))
# Out:
# 3
# 4
#
#
# 2
# 4
#
#
# 3.146
# 2.72
#
#
# 3.0
# 5
#
#
# 8
#
#
# 0

# %%
# Write a script that asks the user to input a number and then displays that number rounded to two decimal places. When run, your program should look like this:
# Enter a number: 5.432
# 5.432 rounded to 2 decimal places is 5.43
no = float(input("please enter number: "))
no1 = round(no,2)
print(f"{no} rounded to 2 decimal places is {no1} ")
# Out:
# please enter number: 5.432
# 5.432 rounded to 2 decimal places is 5.43

# %%
# Write a script that asks the user to input a number and then displays the absolute value of that number.
# When run, your program should look like this:
# Enter a number: -10
# The absolute value of -10 is 10.0
num=float(input("please enter number: "))
print(f"The absolute value of {num} is {abs(num)}")
# Out:
# please enter number: -10
# The absolute value of -10.0 is 10.0

# %%
# Write a script that asks the user to input two numbers by using the
# input() function twice, then display whether or not the difference between those two number is an integer.
# When run, your program should look like this:
# Enter a number: 1.5
# Enter another number: .5
# The difference between 1.5 and .5 is an integer? True!
# If the user inputs two numbers whose difference is not integral, the output should look like this:
# Enter a number: 1.5
# Enter another number: 1.0
# The difference between 1.5 and 1.0 is an integer? False!
num1=float(input("please enter number "))
num2=float((input("please enter another number ")))
print(f"the difference between {num1} and {num2} is integer:"
f"{(num1 - num2).is_integer() }!")
# Out:
# please enter number 1.5
# please enter another number 0.5
# the difference between 1.5 and 0.5 is integer:True!

# %%
#  Print Numbers in Style
num = 1234567890
print(f"add comma to the numbers with thousands" f"\n The value of n is {num:,}")

print("\n")
n = 1
print(f"number upto 2 decimals" f"\nThe value of n is {n:.2f}")

print("\n")
print(f"number upto 3 decimals" f"\nThe value of n is {n:.3f}")

num2 = 1234.56
print("\n")
print(f" here the number is separated by comma and also decimals upto 2" f"\nThe value of n is {num2:,.2f}")
print("\n")

print(f"The specifier ,.2f is useful for displaying currency values:")
balance = 2000.0
spent = 256.35
remaining = balance - spent
print(f"After spending ${spent:.2f}, I was left with ${remaining:,.2f}")
# Out:
# add comma to the numbers with thousands
#  The value of n is 1,234,567,890
#
#
# number upto 2 decimals
# The value of n is 1.00
#
#
# number upto 3 decimals
# The value of n is 1.000
#
#
#  here the number is separated by comma and also decimals upto 2
# The value of n is 1,234.56
#
#
# The specifier ,.2f is useful for displaying currency values:
# After spending $256.35, I was left with $1,743.65

# %%
print(f"The % option should always go at the end of your formatting specification, and you can’t mix it with the f option.")
ratio = 0.9
print(f"Over {ratio:.1%} of Pythonistas say 'Real Python rocks!'")
# Out:
# The % option should always go at the end of your formatting specification, and you can’t mix it with the f option.
# Over 90.0% of Pythonistas say 'Real Python rocks!'

# %%
# Print the result of the calculation 3 ** .125 as a fixed-point number with three decimal places.
num=3 ** 0.125
print(f"{num:.3f}")
# Out:
# 1.147

# %%
# Print the number 150000 as currency, with the thousands grouped with commas.
#Currency should be displayed with two decimal places.
print(f"${150000:.2f}")
# Out:
# $150000.00

# %%
# Print the result of 2 / 10 as a percentage with no decimal places.
# The output should look like 20%.
print(f"{2/10:.1%}")
# Out:
# 20.0%

# %% [markdown]
# Complex Numbers

# %%
n=1+2j
print(n)
print(n.real)
print(n.imag)
print(n.conjugate())
# Out:
# (1+2j)
# 1.0
# 2.0
# (1-2j)
